# %%
print("Hello World!!")

# %%
dbutils.fs.ls("dbfs:/databricks-datasets")

# %%
dbutils.fs.ls("dbfs:/databricks-datasets/bikeSharing/data-001")

# %%
df_day = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/databricks-datasets/bikeSharing/data-001/day.csv")

# display(df_day)
df_day_pandas = df_day.toPandas()
df_day_pandas.head()
# df_day_pandas.describe()
# df_day_pandas.info()

# %%
df_hour = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/databricks-datasets/bikeSharing/data-001/hour.csv")

# display(df_hour)

df_hour_pandas = df_hour.toPandas()
df_hour_pandas.head()
# df_hour_pandas.describe()
# df_hour_pandas.info()

# %%
df = spark.read.parquet("dbfs:/databricks-datasets/credit-card-fraud/data/")
df.show()

# %%
df = spark.read.format("parquet") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/databricks-datasets/credit-card-fraud/data/")

# %% [markdown]
# Read (all files together)
#    ↓
# Save as Delta (Bronze)
#    ↓
# Clean + validate (Silver)
#    ↓
# Feature engineering
#    ↓
# Train ML model
#    ↓
# Track with MLflow

# %%
df = spark.read.parquet("dbfs:/databricks-datasets/credit-card-fraud/data/")

display(df.limit(5))
